# %% [markdown]
# ## Import the libraries

# %%
 #Data handling libraries
import pandas
# Others

# %% [markdown]
# ## Load the data
# Using the pandas library

# %%
# Read the csv file
df = pandas.read_csv('data_dog.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 846 entries, 0 to 845
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   size_dog                 846 non-null    int64
#  1   eye_circularity          841 non-null    float64
#  2   skull_circularity        842 non-null    float64
#  3   ear_size                 840 non-null    float64
#  4   eyes_distance            844 non-null    float64
#  5   ear_form                 846 non-null    int64
#  6   hair_tone                845 non-null    float64
#  7   nose_elongatedness       845 non-null    float64
#  8   weight_dog               843 non-null    float64
#  9   muzzle_form              846 non-null    int64
#  10  skin_tone_main           843 non-null    float64
#  11  skin_pattern_complexity  844 non-null    float64
#  12  body_length              844 non-null    float64
#  13  tail_length              842 non-null    float64
# ...

# %%
df.describe().T
# Out:
#                          count        mean         std    min     25%    50%  \
# size_dog                 846.0   93.678487    8.234474   73.0   87.00   93.0
# eye_circularity          841.0   44.828775    6.152172   33.0   40.00   44.0
# skull_circularity        842.0   82.110451   15.778292   40.0   70.00   80.0
# ear_size                 840.0  168.888095   33.520198  104.0  141.00  167.0
# eyes_distance            844.0   61.678910    7.891463   47.0   57.00   61.0
# ear_form                 846.0    8.567376    4.601217    2.0    7.00    8.0
# hair_tone                845.0  168.901775   33.214848  112.0  147.00  157.0
# nose_elongatedness       845.0   40.933728    7.816186   26.0   33.00   43.0
# weight_dog               843.0   20.582444    2.592933   17.0   19.00   20.0
# muzzle_form              846.0  147.998818   14.515652  118.0  137.00  146.0
# skin_tone_main           843.0  188.631079   31.411004  130.0  167.00  179.0
# ...

# %%
df.head()
# Out:
#    size_dog  eye_circularity  skull_circularity  ear_size  eyes_distance  \
# 0        95             48.0               83.0     178.0           72.0
# 1        91             41.0               84.0     141.0           57.0
# 2       104             50.0              106.0     209.0           66.0
# 3        93             41.0               82.0     159.0           63.0
# 4        85             44.0               70.0     205.0          103.0
#
#    ear_form  hair_tone  nose_elongatedness  weight_dog  muzzle_form  \
# 0        10      162.0                42.0        20.0          159
# 1         9      149.0                45.0        19.0          143
# 2        10      207.0                32.0        23.0          158
# 3         9      144.0                46.0        19.0          143
# 4        52      149.0                45.0        19.0          144
#
#    skin_tone_main  skin_pattern_complexity  body_length  tail_length  \
# ...

# %%
df.dtypes
# Out:
# size_dog                     int64
# eye_circularity            float64
# skull_circularity          float64
# ear_size                   float64
# eyes_distance              float64
# ear_form                     int64
# hair_tone                  float64
# nose_elongatedness         float64
# weight_dog                 float64
# muzzle_form                  int64
# skin_tone_main             float64
# skin_pattern_complexity    float64
# body_length                float64
# tail_length                float64
# hair_curlness              float64
# hair_length                float64
# leg_front_number           float64
# leg_back_number              int64
# breuni_class                object
# dtype: object

# %%
df.shape
# Out:
# (846, 19)

# %%
complete_columns = list(df.columns)

# %%
complete_columns
# Out:
# ['size_dog',
#  'eye_circularity',
#  'skull_circularity',
#  'ear_size',
#  'eyes_distance',
#  'ear_form',
#  'hair_tone',
#  'nose_elongatedness',
#  'weight_dog',
#  'muzzle_form',
#  'skin_tone_main',
#  'skin_pattern_complexity',
#  'body_length',
#  'tail_length',
#  'hair_curlness',
#  'hair_length',
#  'leg_front_number',
#  'leg_back_number',
#  'breuni_class']

# %%
list(df.dropna(thresh=int(df.shape[0] * .9), axis=1).columns)
# Out:
# ['size_dog',
#  'eye_circularity',
#  'skull_circularity',
#  'ear_size',
#  'eyes_distance',
#  'ear_form',
#  'hair_tone',
#  'nose_elongatedness',
#  'weight_dog',
#  'muzzle_form',
#  'skin_tone_main',
#  'skin_pattern_complexity',
#  'body_length',
#  'tail_length',
#  'hair_curlness',
#  'hair_length',
#  'leg_front_number',
#  'leg_back_number',
#  'breuni_class']

# %%
incomplete_columns = list(df.columns[df.isnull().any()])
incomplete_columns
# Out:
# ['eye_circularity',
#  'skull_circularity',
#  'ear_size',
#  'eyes_distance',
#  'hair_tone',
#  'nose_elongatedness',
#  'weight_dog',
#  'skin_tone_main',
#  'skin_pattern_complexity',
#  'body_length',
#  'tail_length',
#  'hair_curlness',
#  'hair_length',
#  'leg_front_number']

# %%
for col in incomplete_columns:
    num_missing = df[df[col].isnull() == True].shape[0]
    print('number missing for column {}: {}'.format(col,
                                                    num_missing))
# Out:
# number missing for column eye_circularity: 5
# number missing for column skull_circularity: 4
# number missing for column ear_size: 6
# number missing for column eyes_distance: 2
# number missing for column hair_tone: 1
# number missing for column nose_elongatedness: 1
# number missing for column weight_dog: 3
# number missing for column skin_tone_main: 3
# number missing for column skin_pattern_complexity: 2
# number missing for column body_length: 2
# number missing for column tail_length: 4
# number missing for column hair_curlness: 6
# number missing for column hair_length: 1
# number missing for column leg_front_number: 1

# %%
df.eye_circularity.value_counts()
# Out:
# 43.0    59
# 45.0    58
# 44.0    50
# 46.0    48
# 38.0    47
# 42.0    47
# 37.0    42
# 40.0    42
# 39.0    42
# 36.0    41
# 54.0    39
# 47.0    36
# 41.0    35
# 55.0    33
# 48.0    31
# 53.0    30
# 51.0    29
# 49.0    28
# 52.0    28
# 35.0    16
# 50.0    16
# 56.0    15
# 57.0    12
# 34.0     9
# 58.0     5
# 33.0     2
# 59.0     1
# Name: eye_circularity, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 846 entries, 0 to 845
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   size_dog                 846 non-null    int64
#  1   eye_circularity          841 non-null    float64
#  2   skull_circularity        842 non-null    float64
#  3   ear_size                 840 non-null    float64
#  4   eyes_distance            844 non-null    float64
#  5   ear_form                 846 non-null    int64
#  6   hair_tone                845 non-null    float64
#  7   nose_elongatedness       845 non-null    float64
#  8   weight_dog               843 non-null    float64
#  9   muzzle_form              846 non-null    int64
#  10  skin_tone_main           843 non-null    float64
#  11  skin_pattern_complexity  844 non-null    float64
#  12  body_length              844 non-null    float64
#  13  tail_length              842 non-null    float64
# ...

# %%
df.eye_circularity.value_counts()
# Out:
# 43.0    59
# 45.0    58
# 44.0    50
# 46.0    48
# 38.0    47
# 42.0    47
# 37.0    42
# 40.0    42
# 39.0    42
# 36.0    41
# 54.0    39
# 47.0    36
# 41.0    35
# 55.0    33
# 48.0    31
# 53.0    30
# 51.0    29
# 49.0    28
# 52.0    28
# 35.0    16
# 50.0    16
# 56.0    15
# 57.0    12
# 34.0     9
# 58.0     5
# 33.0     2
# 59.0     1
# Name: eye_circularity, dtype: int64

# %%
means=df["eye_circularity"].mean()
means
# Out:
# 44.828775267538646

# %%
df.eye_circularity = df.eye_circularity.fillna(44.8)

# %%
df.eye_circularity.value_counts()
# Out:
# 43.0    59
# 45.0    58
# 44.0    50
# 46.0    48
# 38.0    47
# 42.0    47
# 40.0    42
# 39.0    42
# 37.0    42
# 36.0    41
# 54.0    39
# 47.0    36
# 41.0    35
# 55.0    33
# 48.0    31
# 53.0    30
# 51.0    29
# 49.0    28
# 52.0    28
# 35.0    16
# 50.0    16
# 56.0    15
# 57.0    12
# 34.0     9
# 44.8     5
# 58.0     5
# 33.0     2
# 59.0     1
# Name: eye_circularity, dtype: int64

# %%
df[df.isna().any(axis=1)]
# Out:
#      size_dog  eye_circularity  skull_circularity  ear_size  eyes_distance  \
# 9          93             44.0               98.0       NaN           62.0
# 19        101             56.0              100.0     215.0            NaN
# 35        100             46.0                NaN     172.0           67.0
# 66         81             43.0               68.0     125.0           57.0
# 70         96             55.0               98.0     161.0           54.0
# 77         86             40.0               62.0     140.0           62.0
# 78        104             52.0               94.0       NaN           66.0
# 105       108             44.8              103.0     202.0           64.0
# 118        85             44.8                NaN     128.0           56.0
# 141        81             42.0               63.0     125.0           55.0
# 159        91             45.0               75.0       NaN           57.0
# ...

# %%
means=df["skull_circularity"].mean()
means
# Out:
# 82.1104513064133

# %%
for col in incomplete_columns:
    num_missing = df[df[col].isnull() == True].shape[0]
    print('number missing for column {}: {}'.format(col,
                                                    num_missing))
# Out:
# number missing for column eye_circularity: 0
# number missing for column skull_circularity: 4
# number missing for column ear_size: 6
# number missing for column eyes_distance: 2
# number missing for column hair_tone: 1
# number missing for column nose_elongatedness: 1
# number missing for column weight_dog: 3
# number missing for column skin_tone_main: 3
# number missing for column skin_pattern_complexity: 2
# number missing for column body_length: 2
# number missing for column tail_length: 4
# number missing for column hair_curlness: 6
# number missing for column hair_length: 1
# number missing for column leg_front_number: 1

# %%
df.skull_circularity = df.skull_circularity.fillna(82.0)

# %%
means1=df["eyes_distance"].mean()
means2=df["hair_tone"].mean()
means3=df["nose_elongatedness"].mean()
means4=df["weight_dog"].mean()
means5=df["skin_tone_main"].mean()
means6=df["skin_pattern_complexity"].mean()
means7=df["body_length"].mean()
means8=df["tail_length"].mean()
means9=df["hair_curlness"].mean()
meansa=df["hair_length"].mean()
meansb=df["leg_front_number"].mean()
meansc=df["ear_size"].mean()
means1,means2,means3,means4,means5,means6,means7,means8,means9,meansa,meansb,meansc
# Out:
# (61.677304964539005,
#  168.9018912529551,
#  40.9338061465721,
#  20.583924349881798,
#  188.63238770685578,
#  439.4929078014184,
#  174.71040189125296,
#  72.44562647754137,
#  6.361702127659575,
#  12.602836879432624,
#  188.91962174940898,
#  168.88809523809525)

# %%
df.ear_size=df.ear_size.fillna(meansc)

# %%
df.eyes_distance = df.eyes_distance.fillna(61.0)
df.hair_tone = df.hair_tone.fillna(169.0)
df.nose_elongatedness = df.nose_elongatedness.fillna(41.0)
df.weight_dog = df.weight_dog.fillna(21.0)
df.skin_tone_main = df.skin_tone_main.fillna(189.0)
df.skin_pattern_complexity = df.skin_pattern_complexity.fillna(439.0)
df.body_length = df.body_length.fillna(175.0)
df.tail_length = df.tail_length.fillna(72.0)
df.hair_curlness = df.hair_curlness.fillna(6.0)
df.hair_length = df.hair_length.fillna(13.0)
df.leg_front_number = df.leg_front_number.fillna(189.0)

# %%
df[df.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [size_dog, eye_circularity, skull_circularity, ear_size, eyes_distance, ear_form, hair_tone, nose_elongatedness, weight_dog, muzzle_form, skin_tone_main, skin_pattern_complexity, body_length, tail_length, hair_curlness, hair_length, leg_front_number, leg_back_number, breuni_class]
# Index: []

# %%
df.corr()
# Out:
# /var/folders/sh/cyp7qzhj0r91hj2jflxhv_lh0000gn/T/ipykernel_3337/1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                          size_dog  eye_circularity  skull_circularity  \
# size_dog                 1.000000         0.685404           0.789912
# eye_circularity          0.685404         1.000000           0.792991
# skull_circularity        0.789912         0.792991           1.000000
# ear_size                 0.689840         0.620975           0.767094
# eyes_distance            0.091534         0.153113           0.158296
# ear_form                 0.148249         0.251217           0.264558
# hair_tone                0.812231         0.848169           0.904394
# nose_elongatedness      -0.788647        -0.821888          -0.911434
# ...

# %%
df.var()
# Out:
# /var/folders/sh/cyp7qzhj0r91hj2jflxhv_lh0000gn/T/ipykernel_3337/1568254755.py:1: FutureWarning: The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.var()
# size_dog                      67.806566
# eye_circularity               37.625264
# skull_circularity            247.776067
# ear_size                    1115.625421
# eyes_distance                 62.128881
# ear_form                      21.171195
# hair_tone                   1101.920541
# nose_elongatedness            61.020465
# weight_dog                     6.700049
# muzzle_form                  210.704141
# skin_tone_main               983.148725
# skin_pattern_complexity    31137.322435
# body_length                 1059.256862
# tail_length                   55.778697
# ...

# %%
testgithub= 'try ob ich pushen und pullen kann'
testgithub
# Out:
# 'try ob ich pushen und pullen kann'
