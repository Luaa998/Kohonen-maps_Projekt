# %% [markdown]
# ## Import the libraries

# %%
# Data handling libraries
import pandas

# Others

# %% [markdown]
# ## Load the data
# Using the pandas library

# %%
# Read the csv file
df = pandas.read_csv('data_dog.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 846 entries, 0 to 845
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   size_dog                 846 non-null    int64
#  1   eye_circularity          841 non-null    float64
#  2   skull_circularity        842 non-null    float64
#  3   ear_size                 840 non-null    float64
#  4   eyes_distance            844 non-null    float64
#  5   ear_form                 846 non-null    int64
#  6   hair_tone                845 non-null    float64
#  7   nose_elongatedness       845 non-null    float64
#  8   weight_dog               843 non-null    float64
#  9   muzzle_form              846 non-null    int64
#  10  skin_tone_main           843 non-null    float64
#  11  skin_pattern_complexity  844 non-null    float64
#  12  body_length              844 non-null    float64
#  13  tail_length              842 non-null    float64
# ...

# %%
df.describe().T
# Out:
#                          count        mean         std    min     25%    50%  \
# size_dog                 846.0   93.678487    8.234474   73.0   87.00   93.0
# eye_circularity          841.0   44.828775    6.152172   33.0   40.00   44.0
# skull_circularity        842.0   82.110451   15.778292   40.0   70.00   80.0
# ear_size                 840.0  168.888095   33.520198  104.0  141.00  167.0
# eyes_distance            844.0   61.678910    7.891463   47.0   57.00   61.0
# ear_form                 846.0    8.567376    4.601217    2.0    7.00    8.0
# hair_tone                845.0  168.901775   33.214848  112.0  147.00  157.0
# nose_elongatedness       845.0   40.933728    7.816186   26.0   33.00   43.0
# weight_dog               843.0   20.582444    2.592933   17.0   19.00   20.0
# muzzle_form              846.0  147.998818   14.515652  118.0  137.00  146.0
# skin_tone_main           843.0  188.631079   31.411004  130.0  167.00  179.0
# ...

# %%
df.head()
# Out:
#    size_dog  eye_circularity  skull_circularity  ear_size  eyes_distance  \
# 0        95             48.0               83.0     178.0           72.0
# 1        91             41.0               84.0     141.0           57.0
# 2       104             50.0              106.0     209.0           66.0
# 3        93             41.0               82.0     159.0           63.0
# 4        85             44.0               70.0     205.0          103.0
#
#    ear_form  hair_tone  nose_elongatedness  weight_dog  muzzle_form  \
# 0        10      162.0                42.0        20.0          159
# 1         9      149.0                45.0        19.0          143
# 2        10      207.0                32.0        23.0          158
# 3         9      144.0                46.0        19.0          143
# 4        52      149.0                45.0        19.0          144
#
#    skin_tone_main  skin_pattern_complexity  body_length  tail_length  \
# ...

# %%
df.dtypes
# Out:
# size_dog                     int64
# eye_circularity            float64
# skull_circularity          float64
# ear_size                   float64
# eyes_distance              float64
# ear_form                     int64
# hair_tone                  float64
# nose_elongatedness         float64
# weight_dog                 float64
# muzzle_form                  int64
# skin_tone_main             float64
# skin_pattern_complexity    float64
# body_length                float64
# tail_length                float64
# hair_curlness              float64
# hair_length                float64
# leg_front_number           float64
# leg_back_number              int64
# breuni_class                object
# dtype: object

# %%
df.shape
# Out:
# (846, 19)

# %%
complete_columns = list(df.columns)

# %%
complete_columns
# Out:
# ['size_dog',
#  'eye_circularity',
#  'skull_circularity',
#  'ear_size',
#  'eyes_distance',
#  'ear_form',
#  'hair_tone',
#  'nose_elongatedness',
#  'weight_dog',
#  'muzzle_form',
#  'skin_tone_main',
#  'skin_pattern_complexity',
#  'body_length',
#  'tail_length',
#  'hair_curlness',
#  'hair_length',
#  'leg_front_number',
#  'leg_back_number',
#  'breuni_class']

# %%
list(df.dropna(thresh=int(df.shape[0] * .9), axis=1).columns)
# Out:
# ['size_dog',
#  'eye_circularity',
#  'skull_circularity',
#  'ear_size',
#  'eyes_distance',
#  'ear_form',
#  'hair_tone',
#  'nose_elongatedness',
#  'weight_dog',
#  'muzzle_form',
#  'skin_tone_main',
#  'skin_pattern_complexity',
#  'body_length',
#  'tail_length',
#  'hair_curlness',
#  'hair_length',
#  'leg_front_number',
#  'leg_back_number',
#  'breuni_class']

# %%
incomplete_columns = list(df.columns[df.isnull().any()])
incomplete_columns
# Out:
# ['eye_circularity',
#  'skull_circularity',
#  'ear_size',
#  'eyes_distance',
#  'hair_tone',
#  'nose_elongatedness',
#  'weight_dog',
#  'skin_tone_main',
#  'skin_pattern_complexity',
#  'body_length',
#  'tail_length',
#  'hair_curlness',
#  'hair_length',
#  'leg_front_number']

# %%
for col in incomplete_columns:
    num_missing = df[df[col].isnull() == True].shape[0]
    print('number missing for column {}: {}'.format(col,
                                                    num_missing))
# Out:
# number missing for column eye_circularity: 5
# number missing for column skull_circularity: 4
# number missing for column ear_size: 6
# number missing for column eyes_distance: 2
# number missing for column hair_tone: 1
# number missing for column nose_elongatedness: 1
# number missing for column weight_dog: 3
# number missing for column skin_tone_main: 3
# number missing for column skin_pattern_complexity: 2
# number missing for column body_length: 2
# number missing for column tail_length: 4
# number missing for column hair_curlness: 6
# number missing for column hair_length: 1
# number missing for column leg_front_number: 1

# %%
df.eye_circularity.value_counts()
# Out:
# 43.0    59
# 45.0    58
# 44.0    50
# 46.0    48
# 38.0    47
# 42.0    47
# 37.0    42
# 40.0    42
# 39.0    42
# 36.0    41
# 54.0    39
# 47.0    36
# 41.0    35
# 55.0    33
# 48.0    31
# 53.0    30
# 51.0    29
# 49.0    28
# 52.0    28
# 35.0    16
# 50.0    16
# 56.0    15
# 57.0    12
# 34.0     9
# 58.0     5
# 33.0     2
# 59.0     1
# Name: eye_circularity, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 846 entries, 0 to 845
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   size_dog                 846 non-null    int64
#  1   eye_circularity          841 non-null    float64
#  2   skull_circularity        842 non-null    float64
#  3   ear_size                 840 non-null    float64
#  4   eyes_distance            844 non-null    float64
#  5   ear_form                 846 non-null    int64
#  6   hair_tone                845 non-null    float64
#  7   nose_elongatedness       845 non-null    float64
#  8   weight_dog               843 non-null    float64
#  9   muzzle_form              846 non-null    int64
#  10  skin_tone_main           843 non-null    float64
#  11  skin_pattern_complexity  844 non-null    float64
#  12  body_length              844 non-null    float64
#  13  tail_length              842 non-null    float64
# ...

# %%
df.eye_circularity.value_counts()
# Out:
# 43.0    59
# 45.0    58
# 44.0    50
# 46.0    48
# 38.0    47
# 42.0    47
# 40.0    42
# 39.0    42
# 37.0    42
# 36.0    41
# 54.0    39
# 47.0    36
# 41.0    35
# 55.0    33
# 48.0    31
# 53.0    30
# 51.0    29
# 49.0    28
# 52.0    28
# 35.0    16
# 50.0    16
# 56.0    15
# 57.0    12
# 34.0     9
# 44.8     5
# 58.0     5
# 33.0     2
# 59.0     1
# Name: eye_circularity, dtype: int64

# %%
median=df["eye_circularity"].median()
median
# Out:
# 44.0

# %%
df.eye_circularity = df.eye_circularity.fillna(median)

# %%
df.eye_circularity.value_counts()
# Out:
# 43.0    59
# 45.0    58
# 44.0    55
# 46.0    48
# 38.0    47
# 42.0    47
# 37.0    42
# 40.0    42
# 39.0    42
# 36.0    41
# 54.0    39
# 47.0    36
# 41.0    35
# 55.0    33
# 48.0    31
# 53.0    30
# 51.0    29
# 49.0    28
# 52.0    28
# 35.0    16
# 50.0    16
# 56.0    15
# 57.0    12
# 34.0     9
# 58.0     5
# 33.0     2
# 59.0     1
# Name: eye_circularity, dtype: int64

# %%
df[df.isna().any(axis=1)]
# Out:
#      size_dog  eye_circularity  skull_circularity  ear_size  eyes_distance  \
# 9          93             44.0               98.0       NaN           62.0
# 19        101             56.0              100.0     215.0            NaN
# 35        100             46.0                NaN     172.0           67.0
# 66         81             43.0               68.0     125.0           57.0
# 70         96             55.0               98.0     161.0           54.0
# 77         86             40.0               62.0     140.0           62.0
# 78        104             52.0               94.0       NaN           66.0
# 105       108             44.0              103.0     202.0           64.0
# 118        85             44.0                NaN     128.0           56.0
# 141        81             42.0               63.0     125.0           55.0
# 159        91             45.0               75.0       NaN           57.0
# ...

# %%
median1=df["skull_circularity"].median()
median1
# Out:
# 80.0

# %%
df.skull_circularity = df.skull_circularity.fillna(median1)

# %%
df[df.isna().any(axis=1)]
# Out:
#      size_dog  eye_circularity  skull_circularity  ear_size  eyes_distance  \
# 9          93             44.0               98.0       NaN           62.0
# 19        101             56.0              100.0     215.0            NaN
# 66         81             43.0               68.0     125.0           57.0
# 70         96             55.0               98.0     161.0           54.0
# 77         86             40.0               62.0     140.0           62.0
# 78        104             52.0               94.0       NaN           66.0
# 105       108             44.0              103.0     202.0           64.0
# 141        81             42.0               63.0     125.0           55.0
# 159        91             45.0               75.0       NaN           57.0
# 177        89             44.0               72.0     160.0           66.0
# 192        93             43.0               76.0     149.0           57.0
# ...

# %%
median_ear_size=df["ear_size"].median()
median_ear_size
# Out:
# 167.0

# %%
df.ear_size = df.ear_size.fillna(median_ear_size)

# %%
df[df.isna().any(axis=1)]
# Out:
#      size_dog  eye_circularity  skull_circularity  ear_size  eyes_distance  \
# 19        101             56.0              100.0     215.0            NaN
# 66         81             43.0               68.0     125.0           57.0
# 70         96             55.0               98.0     161.0           54.0
# 77         86             40.0               62.0     140.0           62.0
# 105       108             44.0              103.0     202.0           64.0
# 141        81             42.0               63.0     125.0           55.0
# 177        89             44.0               72.0     160.0           66.0
# 192        93             43.0               76.0     149.0           57.0
# 207        85             42.0               80.0     121.0           55.0
# 215        90             39.0               86.0     169.0           62.0
# 222       100             50.0               81.0     197.0            NaN
# ...

# %%
median_eyes_distance=df["eyes_distance"].median()
median_eyes_distance
# Out:
# 61.0

# %%
df.eyes_distance = df.eyes_distance.fillna(median_eyes_distance)

# %%
df[df.isna().any(axis=1)]
# Out:
#      size_dog  eye_circularity  skull_circularity  ear_size  eyes_distance  \
# 66         81             43.0               68.0     125.0           57.0
# 70         96             55.0               98.0     161.0           54.0
# 77         86             40.0               62.0     140.0           62.0
# 105       108             44.0              103.0     202.0           64.0
# 141        81             42.0               63.0     125.0           55.0
# 177        89             44.0               72.0     160.0           66.0
# 192        93             43.0               76.0     149.0           57.0
# 207        85             42.0               80.0     121.0           55.0
# 215        90             39.0               86.0     169.0           62.0
# 222       100             50.0               81.0     197.0           61.0
# 237        85             45.0               65.0     128.0           56.0
# ...

# %%
median_hair_tone=df["hair_tone"].median()
median_hair_tone
# Out:
# 157.0

# %%
df.hair_tone = df.hair_tone.fillna(median_hair_tone)

# %%
df[df.isna().any(axis=1)]
# Out:
#      size_dog  eye_circularity  skull_circularity  ear_size  eyes_distance  \
# 66         81             43.0               68.0     125.0           57.0
# 70         96             55.0               98.0     161.0           54.0
# 77         86             40.0               62.0     140.0           62.0
# 105       108             44.0              103.0     202.0           64.0
# 141        81             42.0               63.0     125.0           55.0
# 177        89             44.0               72.0     160.0           66.0
# 192        93             43.0               76.0     149.0           57.0
# 207        85             42.0               80.0     121.0           55.0
# 215        90             39.0               86.0     169.0           62.0
# 222       100             50.0               81.0     197.0           61.0
# 237        85             45.0               65.0     128.0           56.0
# ...

# %%
median_nose_elongatedness=df["nose_elongatedness"].median()
median_nose_elongatedness
# Out:
# 43.0

# %%
df.nose_elongatedness = df.nose_elongatedness.fillna(median_nose_elongatedness)

# %%
df[df.isna().any(axis=1)]
# Out:
#      size_dog  eye_circularity  skull_circularity  ear_size  eyes_distance  \
# 66         81             43.0               68.0     125.0           57.0
# 70         96             55.0               98.0     161.0           54.0
# 77         86             40.0               62.0     140.0           62.0
# 105       108             44.0              103.0     202.0           64.0
# 141        81             42.0               63.0     125.0           55.0
# 177        89             44.0               72.0     160.0           66.0
# 192        93             43.0               76.0     149.0           57.0
# 207        85             42.0               80.0     121.0           55.0
# 222       100             50.0               81.0     197.0           61.0
# 237        85             45.0               65.0     128.0           56.0
# 249        85             34.0               53.0     127.0           58.0
# ...

# %%
median_weight_dog=df["weight_dog"].median()
median_weight_dog
# Out:
# 20.0

# %%
df.weight_dog = df.weight_dog.fillna(median_weight_dog)

# %%
df[df.isna().any(axis=1)]
# Out:
#      size_dog  eye_circularity  skull_circularity  ear_size  eyes_distance  \
# 66         81             43.0               68.0     125.0           57.0
# 77         86             40.0               62.0     140.0           62.0
# 105       108             44.0              103.0     202.0           64.0
# 141        81             42.0               63.0     125.0           55.0
# 177        89             44.0               72.0     160.0           66.0
# 192        93             43.0               76.0     149.0           57.0
# 207        85             42.0               80.0     121.0           55.0
# 222       100             50.0               81.0     197.0           61.0
# 249        85             34.0               53.0     127.0           58.0
# 266        86             44.0               65.0     116.0           53.0
# 285        89             48.0               85.0     189.0           64.0
# ...

# %%
median_skin_tone_main=df["skin_tone_main"].median()
median_skin_tone_main
# Out:
# 179.0

# %%
df.skin_tone_main = df.skin_tone_main.fillna(median_skin_tone_main)

# %%
df[df.isna().any(axis=1)]
# Out:
#      size_dog  eye_circularity  skull_circularity  ear_size  eyes_distance  \
# 66         81             43.0               68.0     125.0           57.0
# 77         86             40.0               62.0     140.0           62.0
# 105       108             44.0              103.0     202.0           64.0
# 141        81             42.0               63.0     125.0           55.0
# 177        89             44.0               72.0     160.0           66.0
# 192        93             43.0               76.0     149.0           57.0
# 207        85             42.0               80.0     121.0           55.0
# 222       100             50.0               81.0     197.0           61.0
# 249        85             34.0               53.0     127.0           58.0
# 266        86             44.0               65.0     116.0           53.0
# 285        89             48.0               85.0     189.0           64.0
# ...

# %%
median_skin_pattern_complexity=df["skin_pattern_complexity"].median()
median_skin_pattern_complexity
# Out:
# 363.5

# %%
df.skin_pattern_complexity = df.skin_pattern_complexity.fillna(median_skin_pattern_complexity)

# %%
df[df.isna().any(axis=1)]
# Out:
#      size_dog  eye_circularity  skull_circularity  ear_size  eyes_distance  \
# 66         81             43.0               68.0     125.0           57.0
# 77         86             40.0               62.0     140.0           62.0
# 105       108             44.0              103.0     202.0           64.0
# 141        81             42.0               63.0     125.0           55.0
# 177        89             44.0               72.0     160.0           66.0
# 192        93             43.0               76.0     149.0           57.0
# 207        85             42.0               80.0     121.0           55.0
# 222       100             50.0               81.0     197.0           61.0
# 249        85             34.0               53.0     127.0           58.0
# 266        86             44.0               65.0     116.0           53.0
# 285        89             48.0               85.0     189.0           64.0
# ...

# %%
median_body_length=df["body_length"].median()
median_body_length
# Out:
# 173.5

# %%
df.body_length = df.body_length.fillna(median_body_length)

# %%
df[df.isna().any(axis=1)]
# Out:
#      size_dog  eye_circularity  skull_circularity  ear_size  eyes_distance  \
# 66         81             43.0               68.0     125.0           57.0
# 77         86             40.0               62.0     140.0           62.0
# 105       108             44.0              103.0     202.0           64.0
# 141        81             42.0               63.0     125.0           55.0
# 177        89             44.0               72.0     160.0           66.0
# 192        93             43.0               76.0     149.0           57.0
# 222       100             50.0               81.0     197.0           61.0
# 249        85             34.0               53.0     127.0           58.0
# 285        89             48.0               85.0     189.0           64.0
# 329        89             38.0               80.0     169.0           59.0
# 419        93             34.0               72.0     144.0           56.0
#
# ...

# %%
median_tail_length=df["tail_length"].median()
median_tail_length
# Out:
# 71.5

# %%
df.tail_length = df.body_length.fillna(median_tail_length)

# %%
df[df.isna().any(axis=1)]
# Out:
#      size_dog  eye_circularity  skull_circularity  ear_size  eyes_distance  \
# 66         81             43.0               68.0     125.0           57.0
# 105       108             44.0              103.0     202.0           64.0
# 141        81             42.0               63.0     125.0           55.0
# 177        89             44.0               72.0     160.0           66.0
# 222       100             50.0               81.0     197.0           61.0
# 249        85             34.0               53.0     127.0           58.0
# 285        89             48.0               85.0     189.0           64.0
# 419        93             34.0               72.0     144.0           56.0
#
#      ear_form  hair_tone  nose_elongatedness  weight_dog  muzzle_form  \
# 66          8      149.0                46.0        19.0          146
# 105        10      220.0                30.0        25.0          168
# 141         8      149.0                46.0        19.0          145
# ...

# %%
median_hair_curlness=df["hair_curlness"].median()
median_hair_curlness
# Out:
# 6.0

# %%
df.hair_curlness = df.hair_curlness.fillna(median_hair_curlness)

# %%
df[df.isna().any(axis=1)]
# Out:
#      size_dog  eye_circularity  skull_circularity  ear_size  eyes_distance  \
# 105       108             44.0              103.0     202.0           64.0
# 419        93             34.0               72.0     144.0           56.0
#
#      ear_form  hair_tone  nose_elongatedness  weight_dog  muzzle_form  \
# 105        10      220.0                30.0        25.0          168
# 419         6      133.0                50.0        18.0          123
#
#      skin_tone_main  skin_pattern_complexity  body_length  tail_length  \
# 105           179.0                    711.0        214.0        214.0
# 419           158.0                    263.0        125.0        125.0
#
#      hair_curlness  hair_length  leg_front_number  leg_back_number  \
# 105           11.0          NaN             188.0              199
# 419            5.0         20.0               NaN              206
#
#     breuni_class
# 105  main_stream
# 419  main_stream

# %%
median_hair_length=df["hair_length"].median()
median_hair_length
# Out:
# 11.0

# %%
df.hair_length = df.hair_length.fillna(median_hair_length)

# %%
df[df.isna().any(axis=1)]
# Out:
#      size_dog  eye_circularity  skull_circularity  ear_size  eyes_distance  \
# 419        93             34.0               72.0     144.0           56.0
#
#      ear_form  hair_tone  nose_elongatedness  weight_dog  muzzle_form  \
# 419         6      133.0                50.0        18.0          123
#
#      skin_tone_main  skin_pattern_complexity  body_length  tail_length  \
# 419           158.0                    263.0        125.0        125.0
#
#      hair_curlness  hair_length  leg_front_number  leg_back_number  \
# 419            5.0         20.0               NaN              206
#
#     breuni_class
# 419  main_stream

# %%
median_leg_front_number=df["leg_front_number"].median()
median_leg_front_number
# Out:
# 188.0

# %%
df.leg_front_number = df.leg_front_number.fillna(median_leg_front_number)

# %%
df[df.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [size_dog, eye_circularity, skull_circularity, ear_size, eyes_distance, ear_form, hair_tone, nose_elongatedness, weight_dog, muzzle_form, skin_tone_main, skin_pattern_complexity, body_length, tail_length, hair_curlness, hair_length, leg_front_number, leg_back_number, breuni_class]
# Index: []

# %%
df.head(20)
# Out:
#     size_dog  eye_circularity  skull_circularity  ear_size  eyes_distance  \
# 0         95             48.0               83.0     178.0           72.0
# 1         91             41.0               84.0     141.0           57.0
# 2        104             50.0              106.0     209.0           66.0
# 3         93             41.0               82.0     159.0           63.0
# 4         85             44.0               70.0     205.0          103.0
# 5        107             44.0              106.0     172.0           50.0
# 6         97             43.0               73.0     173.0           65.0
# 7         90             43.0               66.0     157.0           65.0
# 8         86             34.0               62.0     140.0           61.0
# 9         93             44.0               98.0     167.0           62.0
# 10        86             36.0               70.0     143.0           61.0
# 11        90             34.0               66.0     136.0           55.0
# ...

# %%
df.describe().T
# Out:
#                          count        mean         std    min     25%    50%  \
# size_dog                 846.0   93.678487    8.234474   73.0   87.00   93.0
# eye_circularity          846.0   44.823877    6.134272   33.0   40.00   44.0
# skull_circularity        846.0   82.100473   15.741569   40.0   70.00   80.0
# ear_size                 846.0  168.874704   33.401356  104.0  141.00  167.0
# eyes_distance            846.0   61.677305    7.882188   47.0   57.00   61.0
# ear_form                 846.0    8.567376    4.601217    2.0    7.00    8.0
# hair_tone                846.0  168.887707   33.197710  112.0  147.00  157.0
# nose_elongatedness       846.0   40.936170    7.811882   26.0   33.00   43.0
# weight_dog               846.0   20.580378    2.588558   17.0   19.00   20.0
# muzzle_form              846.0  147.998818   14.515652  118.0  137.00  146.0
# skin_tone_main           846.0  188.596927   31.360427  130.0  167.00  179.0
# ...

# %%
df.cov()
# Out:
#                             size_dog  eye_circularity  skull_circularity  \
# size_dog                   67.806566        34.595378         102.393288
# eye_circularity            34.595378        37.629299          76.508841
# skull_circularity         102.393288        76.508841         247.796994
# ear_size                  189.708781       127.220510         403.298994
# eyes_distance               5.941097         7.435406          19.660863
# ear_form                    5.616954         7.097679          19.171329
# hair_tone                 222.142552       172.677241         472.978160
# nose_elongatedness        -50.737706       -39.365101        -112.064585
# weight_dog                 17.344216        13.392280          36.388956
# muzzle_form                80.818554        85.598608         176.978817
# skin_tone_main            196.794514       153.188097         425.299717
# skin_pattern_complexity  1183.048547       905.058993        2461.647662
# ...

# %%
df.corr()
# Out:
#                          size_dog  eye_circularity  skull_circularity  \
# size_dog                 1.000000         0.684887           0.789928
# eye_circularity          0.684887         1.000000           0.792320
# skull_circularity        0.789928         0.792320           1.000000
# ear_size                 0.689743         0.620912           0.767035
# eyes_distance            0.091534         0.153778           0.158456
# ear_form                 0.148249         0.251467           0.264686
# hair_tone                0.812620         0.847938           0.905076
# nose_elongatedness      -0.788750        -0.821472          -0.911307
# weight_dog               0.813694         0.843400           0.893025
# muzzle_form              0.676143         0.961318           0.774527
# skin_tone_main           0.762070         0.796306           0.861519
# skin_pattern_complexity  0.814012         0.835946           0.886017
# ...

# %%
df.skew()
# Out:
# <ipython-input-71-9e0b1e29546f>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.skew()
# size_dog                   0.381271
# eye_circularity            0.264928
# skull_circularity          0.108718
# ear_size                   0.397572
# eyes_distance              3.835392
# ear_form                   6.778394
# hair_tone                  0.608710
# nose_elongatedness         0.046951
# weight_dog                 0.774406
# muzzle_form                0.256359
# skin_tone_main             0.655598
# skin_pattern_complexity    0.845345
# body_length                0.279910
# tail_length                0.279910
# hair_curlness              0.780813
# hair_length                0.689014
# leg_front_number           0.249985
# leg_back_number           -0.226341
# dtype: float64

# %%
df.kurtosis()
# Out:
# <ipython-input-72-c7edf97eb14c>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.kurtosis()
# size_dog                   -0.535275
# eye_circularity            -0.910125
# skull_circularity          -0.967704
# ear_size                    0.329029
# eyes_distance              29.968642
# ear_form                   58.375455
# hair_tone                  -0.613414
# nose_elongatedness         -0.864475
# weight_dog                 -0.379654
# muzzle_form                -0.770098
# skin_tone_main              0.131983
# skin_pattern_complexity    -0.196110
# body_length                -0.490306
# tail_length                -0.490306
# hair_curlness               0.117607
# hair_length                -0.140974
# leg_front_number           -0.585847
# leg_back_number            -0.813435
# dtype: float64

# %%
s=11
s
# Out:
# 11
